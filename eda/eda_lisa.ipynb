# %% [markdown]
# # Initial EDA on event dataset (events_combined.csv)

# %%
import pandas as pd
import duckdb
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
# import data from csv-file
df = pd.read_csv("../streamlit/sthlm_puls/src/sthlm_puls/assets/data/events_combined.csv")

df
# Out:
#                 event_id                                               name  \
# 0      Z698xZq2Z1kaPZUZN                                  Christopher Cross
# 1     Z698xZq2Z16vAgbJjd  Matt Rife: Stay Golden World Tour, Platinum Ti...
# 2      Z698xZq2Z1kx9Fbb_                Svartklubben - Mat & Musik i Mörker
# 3     Z698xZq2Z16vjZPaOs                                Rhythm of the Dance
# 4      Z698xZq2Z1kqkAAJo        Stödkonsert för Ukraina: Borys Ljatosjynsky
# ...                  ...                                                ...
# 1185                 NaN                                      Nubiyan Twist
# 1186                 NaN                                    NUET x INNELLEA
# 1187                 NaN                              Eric Gadd x Blacknuss
# 1188                 NaN                                BULLERBYN x VALBORG
# 1189                 NaN                                               Jung
#
# ...

# %%
df.head()
# Out:
#              event_id                                               name  \
# 0   Z698xZq2Z1kaPZUZN                                  Christopher Cross
# 1  Z698xZq2Z16vAgbJjd  Matt Rife: Stay Golden World Tour, Platinum Ti...
# 2   Z698xZq2Z1kx9Fbb_                Svartklubben - Mat & Musik i Mörker
# 3  Z698xZq2Z16vjZPaOs                                Rhythm of the Dance
# 4   Z698xZq2Z1kqkAAJo        Stödkonsert för Ukraina: Borys Ljatosjynsky
#
#                                                  url  \
# 0  https://www.ticketmaster.se/event/christopher-...
# 1  https://www.ticketmaster.se/event/matt-rife-st...
# 2  https://www.ticketmaster.se/event/svartklubben...
# 3  https://www.ticketmaster.se/event/rhythm-of-th...
# 4  https://www.ticketmaster.se/event/stodkonsert-...
#
#                                            image_url        date   time  \
# 0  https://s1.ticketm.net/dam/e/ebc/f9ec9170-cedf...  2026-04-20  19:00
# ...

# %%
# check RangeIndex & non-null
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_id       1105 non-null   str
#  1   name           1190 non-null   str
#  2   url            1190 non-null   str
#  3   image_url      1190 non-null   str
#  4   date           1190 non-null   str
#  5   time           618 non-null    str
#  6   status         1190 non-null   str
#  7   segment        1190 non-null   str
#  8   genre          998 non-null    str
#  9   subgenre       913 non-null    str
#  10  venue_name     1173 non-null   str
#  11  venue_city     1170 non-null   str
#  12  venue_address  1186 non-null   str
#  13  venue_lat      1190 non-null   float64
#  14  venue_lon      1190 non-null   float64
#  15  day_of_week    1190 non-null   str
#  16  month_name     1190 non-null   str
#  17  month_num      1190 non-null   int64
#  18  year           1190 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['event_id', 'name', 'url', 'image_url', 'date', 'time', 'status',
#        'segment', 'genre', 'subgenre', 'venue_name', 'venue_city',
#        'venue_address', 'venue_lat', 'venue_lon', 'day_of_week', 'month_name',
#        'month_num', 'year', 'hour', 'source'],
#       dtype='str')

# %%
# descriptive statistics of summative statistics (only numerical columns)
df.describe().T
# Out:
#             count         mean       std          min          25%  \
# venue_lat  1190.0    59.351982  0.135948    58.957408    59.313946
# venue_lon  1190.0    18.104455  0.176580    17.398113    18.055700
# month_num  1190.0     6.536975  2.653825     1.000000     5.000000
# year       1190.0  2026.031092  0.173641  2026.000000  2026.000000
# hour        618.0    18.095469  2.970784     0.000000    18.000000
#
#                   50%          75%          max
# venue_lat    59.32457    59.334200    59.993330
# venue_lon    18.07384    18.096259    18.920662
# month_num     5.00000     9.000000    12.000000
# year       2026.00000  2026.000000  2027.000000
# hour         19.00000    20.000000    23.000000

# %%
# check number of rows and columns
print(f"Rows: {df.shape[0]}, Cols: {df.shape[1]}")
# Out:
# Rows: 1190, Cols: 21

# %%
df["segment"].value_counts()
# Out:
# segment
# Arts & Theatre    527
# Music             424
# Miscellaneous     125
# Nightlife          85
# Sports             29
# Name: count, dtype: int64

# %%
df["genre"].value_counts()
# Out:
# genre
# Jazz & Blues               231
# Theatre                    183
# Comedy                      82
# Jazz/Klubb                  81
# Rock                        54
# Film                        54
# Culture & Arts              52
# Dance                       51
# Other                       37
# Food & Drink                26
# Games & Championships       25
# Hip-Hop/Rap                 19
# Family                      15
# Conventions & Fairs         14
# Magic & Illusion            10
# Dance/Electronic             9
# Classical                    7
# Spectacular                  7
# Folk                         6
# Alternative                  4
# Klubb/Konsert                4
# Fairs & Festivals            3
# World                        3
# Miscellaneous                3
# Latin                        3
# Children's Theatre           3
# Blues                        2
# Metal                        2
# Soccer                       2
# Martial Arts                 1
# ...

# %%
# how many different events do we have?
duckdb.sql("""--sql
SELECT
DISTINCT(name)
FROM df
""")
# Out:
# ┌────────────────────────────────────────────────────────┐
# │                          name                          │
# │                        varchar                         │
# ├────────────────────────────────────────────────────────┤
# │ Teorin om relativitet                                  │
# │ Aleks: Tillsammans                                     │
# │ Ásgeir                                                 │
# │ Courtney May Robertson - HUNTER                        │
# │ Erik Grönwall - SLUTSÅLT                               │
# │ Tower of Power                                         │
# │ Molotov + La Mala Rodriguez                            │
# │ Katie Melua                                            │
# │ Dansens Hus – KLUBB DH Hösten 2025 - Hösten 2026       │
# │ The Weeknd: After Hours Til Dawn Tour | Hotel Packages │
# │        ·                                               │
# │        ·                                               │
# ...

# %%
# how many, and which events is there a specific date
# using Window functions OVER() to aggregate over the full result set
duckdb.sql("""
SELECT
    name,
    venue_name,
    date,
    COUNT(*) OVER(PARTITION BY venue_name) AS number_events
FROM df
WHERE date = '2026-05-20'
    ORDER BY number_events DESC
""").df()
# Out:
#                              name venue_name        date  number_events
# 0                       Tori Amos     Cirkus  2026-05-20              2
# 1      Tori Amos - Live at Cirkus     Cirkus  2026-05-20              2
# 2               Gunilla Törnfeldt   Fasching  2026-05-20              1
# 3  16 Horsepower – Live at Fållan     Fållan  2026-05-20              1

# %%
# which days has most events?
duckdb.sql("""
SELECT
    date,
    COUNT(*) AS num_events
    FROM df
    GROUP BY date
    ORDER BY num_events DESC
    LIMIT 5
""")
# Out:
# ┌────────────┬────────────┐
# │    date    │ num_events │
# │  varchar   │   int64    │
# ├────────────┼────────────┤
# │ 2026-04-25 │         51 │
# │ 2026-04-20 │         42 │
# │ 2026-05-09 │         33 │
# │ 2026-04-24 │         28 │
# │ 2026-04-30 │         26 │
# └────────────┴────────────┘

# %%
# which event has the most nr of shows?
duckdb.sql("""
SELECT
    name,
    COUNT(*) AS num_shows
    FROM df
    GROUP BY name
    ORDER BY num_shows DESC
    LIMIT 5
""")
# Out:
# ┌────────────────────────────────────────┬───────────┐
# │                  name                  │ num_shows │
# │                varchar                 │   int64   │
# ├────────────────────────────────────────┼───────────┤
# │ MAMMA MIA! THE PARTY                   │        67 │
# │ Torka aldrig tårar utan handskar       │        39 │
# │ Svartklubben - Mat & Musik i Mörker    │        35 │
# │ & Julia                                │        23 │
# │ Fredrik ”Benke” Rydman – Romeo & Julia │        14 │
# └────────────────────────────────────────┴───────────┘

# %%
# which venue has most events booked this week? (week 17)
duckdb.sql("""
SELECT
    venue_name AS venue,
    COUNT(*) AS total_events
FROM df
WHERE date BETWEEN '2026-04-20' AND '2026-04-26'
GROUP BY venue_name
ORDER BY total_events DESC
LIMIT 5
""").df()
# Out:
#               venue  total_events
# 0          Fasching             8
# 1            Cirkus             7
# 2  Allhelgonakyrkan             5
# 3             Rival             5
# 4      Svartklubben             5

# %%
# Which events has missing id's?
duckdb.sql("""
    SELECT source,
           COUNT(*)
               FILTER (WHERE event_id IS NULL) AS null_ids
FROM df
    GROUP BY source""").df()
# Out:
#            source  null_ids
# 0           berns         4
# 1        fasching        81
# 2  visitstockholm         0
# 3    ticketmaster         0

# %% [markdown]
# ## Visualizations

# %%
""" --- Number Of Events Per Genre --- """

result = duckdb.sql("""
SELECT
    genre,
    COUNT(*) AS num_events
    FROM df
    GROUP BY genre
    ORDER BY num_events DESC
    LIMIT 5
""")

plot_df = result.df()

sns.set_theme(style="whitegrid")

plt.figure(figsize=(8, 4))
ax = sns.barplot(
    data=plot_df,
    x="num_events",
    y="genre",
    hue="genre",
    palette="viridis",
    legend=False
)

plt.title("Topp 5 Genrer i Stockholm", fontsize=16)
plt.xlabel("Antal Events", fontsize=12)
plt.ylabel("Genre", fontsize=12)

plt.tight_layout()
plt.savefig("data_images/events_per_genre.png", dpi=300)
plt.show()

# %%
""" --- Number Of Events Over Time In 2026 --- """

result_monthly = duckdb.sql("""
    SELECT
        month_num,
        month_name,
        COUNT(*) AS event_count
    FROM df
    WHERE year = 2026
    GROUP BY month_num, month_name
    ORDER BY month_num
""")

monthly_data = result_monthly.df()

sns.set_theme(style="darkgrid")
plt.figure(figsize=(12, 6))

# Create linechart
ax = sns.lineplot(
    data=monthly_data,
    x='month_name',
    y='event_count',
    marker='o',
    linewidth=3,
    color='lightblue'
)

# Add values (number of events) above marks
for x, y in zip(monthly_data['month_name'], monthly_data['event_count']):
    plt.text(x, y + 5, str(y), color='black', ha="center", fontweight='bold')


plt.title('Event trends in Stockholm 2026 ', fontsize=18, fontweight='bold', pad=25)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of events', fontsize=14)
plt.ylim(0, monthly_data['event_count'].max() + 50)


plt.tight_layout()
plt.savefig("data_images/event_trends_2026.png", dpi=300)
plt.show()

# %%
""" --- Genre Dominance: Summer vs Winter (Stockholm) --- """

query_genres = """
SELECT
    genre,
    COUNT(*) FILTER (WHERE month_num IN (6, 7, 8)) AS Summer,
    COUNT(*) FILTER (WHERE month_num IN (12, 1, 2)) AS Winter
FROM df
WHERE venue_city = 'Stockholm'
GROUP BY genre
HAVING Summer > 0 OR Winter > 0
ORDER BY Summer DESC
LIMIT 10
"""

genre_data = duckdb.sql(query_genres).df()

# Prepare data for Seaborn (melt it)
genre_melted = genre_data.melt(id_vars='genre', var_name='Season', value_name='Count')

plt.figure(figsize=(12, 7))
sns.barplot(data=genre_melted, x='Count', y='genre', hue='Season', palette='coolwarm')

plt.title('Top 10 Genres in Stockholm: Summer vs Winter', fontsize=16, fontweight='bold')
plt.xlabel('Number of Events')
plt.ylabel('Genre')
plt.legend(title='Season')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## EDA on museums data (Stockholm_museum_full.csv)

# %%
m_df = pd.read_csv("../api/Stockholm_museum_full.csv")

m_df.head()
# Out:
#                       event_id                    name  \
# 0  ChIJrymDbVSdX0YRQTLBtPGa8M8              Vasamuseet
# 1  ChIJN5Ta_qqCX0YRMYVG1s-2NSw                 Skansen
# 2  ChIJBf9B06qCX0YRR46XNXjwFUo         ABBA The Museum
# 3  ChIJhaN0M_l3X0YRpOq8uRb_RcA  Fotografiska Stockholm
# 4  ChIJxagZg1OdX0YRGKnPhRyci9c         Nordiska museet
#
#                                    url              venue_name  \
# 0           https://www.vasamuseet.se/              Vasamuseet
# 1              https://www.skansen.se/                 Skansen
# 2       https://www.abbathemuseum.com/         ABBA The Museum
# 3  https://stockholm.fotografiska.com/  Fotografiska Stockholm
# 4       https://www.nordiskamuseet.se/         Nordiska museet
#
#                                        venue_address venue_city  venue_lat  \
# 0      Galärvarvsvägen 14, 115 21 Stockholm, Sverige  Stockholm  59.328023
# 1  Djurgårdsslätten 49-51, 115 21 Stockholm, Sverige  Stockholm  59.326323
# ...

# %%
m_df.shape
# Out:
# (20, 25)

# %%
m_df.columns
# Out:
# Index(['event_id', 'name', 'url', 'venue_name', 'venue_address', 'venue_city',
#        'venue_lat', 'venue_lon', 'rating', 'num_reviews', 'opening_hours',
#        'status', 'segment', 'genre', 'subgenre', 'year', 'month_name',
#        'is_free', 'popularity_score', 'popularity_index', 'adult_price_sek',
#        'child_price_sek', 'free_age_range', 'student_price_sek',
#        'senior_price_sek'],
#       dtype='str')

# %%
m_df["rating"].value_counts()
# Out:
# rating
# 4.5    6
# 4.4    4
# 4.3    4
# 4.8    2
# 4.6    2
# 4.1    1
# 4.2    1
# Name: count, dtype: int64

# %%
m_df["is_free"].value_counts()
# Out:
# is_free
# False    13
# True      7
# Name: count, dtype: int64

# %%
m_df.describe().T
# Out:
#                   count          mean           std          min          25%  \
# venue_lat          20.0     59.331897      0.011870    59.317962    59.326254
# venue_lon          20.0     18.082953      0.015764    18.053878    18.070844
# rating             20.0      4.445000      0.176143     4.100000     4.300000
# num_reviews        20.0  11320.800000  15422.255906  1131.000000  2706.750000
# year               20.0   2026.000000      0.000000  2026.000000  2026.000000
# popularity_score   20.0    408.575000    264.043774   148.000000   227.425000
# popularity_index   20.0     23.825000     24.142186     0.000000     7.250000
# adult_price_sek    20.0    185.750000     70.409984     0.000000   160.000000
# child_price_sek    20.0     40.950000     66.448615     0.000000     0.000000
#
#                           50%          75%           max
# venue_lat           59.328773    59.333457     59.368975
# venue_lon           18.083012    18.092389     18.118803
# ...

# %%
# What are the "free age range" on each museum?
duckdb.sql("""
SELECT name,
       free_age_range,
       child_price_sek FROM m_df""").df()
# Out:
#                                         name          free_age_range  \
# 0                                 Vasamuseet                    0–18
# 1                                    Skansen                    0–15
# 2                            ABBA The Museum                     0–6
# 3                     Fotografiska Stockholm                    0–16
# 4                            Nordiska museet                    3–18
# 5   Naturhistoriska riksmuseet och Cosmonova                    0–17
# 6                            Tekniska museet                     0–6
# 7                             Nationalmuseum                    0–19
# 8                            Nobelprismuseet                    0–18
# 9                          Historiska museet                    0–18
# 10                         The Viking Museum                     0–6
# 11                  Paradox Museum Stockholm  prisinformation saknas
# 12                                Armémuseum                    0–18
# ...

# %% [markdown]
# ## Visualization

# %%
""" --- Top 10 most expensive Museum in Stockholm (for adults) --- """

# 1. Query
adult_prices = duckdb.sql("""
    SELECT
        name AS Museum,
        adult_price_sek
    FROM m_df
    ORDER BY adult_price_sek DESC
    LIMIT 10
""").df()

# 2. Theme
sns.set_theme(style="whitegrid")

# 3. Create graph
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=adult_prices,
    x="Museum",
    y="adult_price_sek",
    palette="magma",
    hue="Museum",
    legend=False
)

# 4. Labels
plt.title("Adult prices per museum in Stockholm", fontsize=16, fontweight="bold", pad=20)
plt.xlabel("Museum", fontsize=12)
plt.ylabel("Price (SEK)", fontsize=12)
plt.xticks(rotation=45, ha="right")

# 5. Save and plot
plt.tight_layout()
# plt.savefig("data_images/adult_prices.png", dpi=300)
plt.show()

# %%
""" --- Child prices at Museum without free entrees --- """

# 1. Query — exclude free museums (price = 0) so they don't clutter the chart
child_prices = duckdb.sql("""
    SELECT
        name AS Museum,
        child_price_sek
    FROM m_df
    WHERE child_price_sek > 0
    ORDER BY child_price_sek DESC
""").df()

# 2. Theme
sns.set_theme(style="ticks")

# 3. Create graph
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=child_prices,
    x="Museum",
    y="child_price_sek",
    palette="magma",
    hue="Museum",
    legend=False
)

# 4. Labels
plt.title("Kids prices per museum in Stockholm", fontsize=16, fontweight="bold", pad=20)
plt.xlabel("Museum", fontsize=12)
plt.ylabel("Price (SEK)", fontsize=12)
plt.xticks(rotation=45, ha="right")

# 5. Save and plot
plt.tight_layout()
# plt.savefig("data_images/child_prices.png", dpi=300)
plt.show()

# %% [markdown]
# # Data Storytelling

# %%
activity = pd.read_csv("../api/museum_activity.csv")
weather = pd.read_csv("../api/stockholm_weather.csv")
events = df
museum = m_df
weather
# Out:
#          date  temp_max  temp_min  precipitation  weathercode  fetched_at
# 0  2026-04-29      12.3       3.9            0.0            3  2026-04-29
# 1  2026-04-30      17.7       7.8            0.5           51  2026-04-29
# 2  2026-05-01      23.4       9.6            0.0            1  2026-04-29
# 3  2026-05-02      22.1      10.6            0.0            3  2026-04-29
# 4  2026-05-03      13.9       7.1            0.3           51  2026-04-29
# 5  2026-05-04      17.8       5.4            0.0            3  2026-04-29
# 6  2026-05-05      13.1       7.1            0.0            3  2026-04-29
# 7  2026-05-06      11.4       4.9            0.0            3  2026-04-29
# 8  2026-05-07      15.2       6.0            0.0            3  2026-04-29
# 9  2026-05-08      12.9       6.1            0.0            2  2026-04-29

# %% [markdown]
# ## Vad händer i veckan? - Evenemang vs väder

# %%
# Hämta veckans väder (7 dagar) - kolla om någon dag sticker ut
vader_result = duckdb.sql("""
    SELECT
        CAST(date AS DATE) AS datum,
        weathercode AS vaderkod,
        ROUND(temp_max) AS temp_max
    FROM weather
    WHERE CAST(date AS DATE) BETWEEN
        (SELECT MIN(CAST(date AS DATE)) FROM weather)
        AND
        (SELECT MIN(CAST(date AS DATE)) FROM weather) + INTERVAL 6 DAYS
    ORDER BY datum
""").df()

vader_result
# Out:
#        datum  vaderkod  temp_max
# 0 2026-04-29         3      12.0
# 1 2026-04-30        51      18.0
# 2 2026-05-01         1      23.0
# 3 2026-05-02         3      22.0
# 4 2026-05-03        51      14.0
# 5 2026-05-04         3      18.0
# 6 2026-05-05         3      13.0

# %%
# Byt ut väderkoderna mot symboler (emojis) - FREDAG HELT KLART BÄST VÄDER!!
def get_icon(code):
    if code == 0:                return "☀️"
    if code in range(1, 2):      return "🌤️"
    if code in range(3,4):       return "🌥️"
    if code in range(45, 49):    return "🌫️"
    if code in range(51, 68):    return "🌧️"
    if code in range(71, 78):    return "🌨️"
    if code in range(80, 83):    return "🌦️"
    if code == 95:               return "⛈️"
    if code == 96:               return "⛈️"
    if code == 99:               return "⛈️"
    return "❓"

vader_result["icon"] = vader_result["vaderkod"].apply(get_icon)

# Ändra dagarna till svenska
dag_mapping = {
    "Mon": "Mån",
    "Tue": "Tis",
    "Wed": "Ons",
    "Thu": "Tor",
    "Fri": "Fre",
    "Sat": "Lör",
    "Sun": "Sön",
}
vader_result["dag"] = pd.to_datetime(vader_result["datum"]).dt.strftime("%a %d/%m")
vader_result["dag"] = vader_result["dag"].replace(dag_mapping, regex=True)

vader_result
# Out:
#        datum  vaderkod  temp_max icon        dag
# 0 2026-04-29         3      12.0   🌥️  Ons 29/04
# 1 2026-04-30        51      18.0   🌧️  Tor 30/04
# 2 2026-05-01         1      23.0   🌤️  Fre 01/05
# 3 2026-05-02         3      22.0   🌥️  Lör 02/05
# 4 2026-05-03        51      14.0   🌧️  Sön 03/05
# 5 2026-05-04         3      18.0   🌥️  Mån 04/05
# 6 2026-05-05         3      13.0   🌥️  Tis 05/05

# %%
# Ta fram antal events per dag
events_per_dag = duckdb.sql("""
    SELECT
        CAST(date AS DATE) AS datum,
        COUNT(*) AS antal_events
    FROM events
    WHERE CAST(date AS DATE) BETWEEN
        (SELECT MIN(CAST(date AS DATE)) FROM weather)
        AND
        (SELECT MIN(CAST(date AS DATE)) FROM weather) + INTERVAL 6 DAYS
    GROUP BY CAST(date AS DATE)
    ORDER BY datum
""").df()

events_per_dag
# Out:
#        datum  antal_events
# 0 2026-04-29            10
# 1 2026-04-30            26
# 2 2026-05-01            20
# 3 2026-05-02            24
# 4 2026-05-03            17
# 5 2026-05-04             4
# 6 2026-05-05             5

# %%
# Joina väder och events
df_merged = vader_result.merge(events_per_dag, on="datum", how="left")
df_merged["antal_events"] = df_merged["antal_events"].fillna(0).astype(int)

df_merged
# Out:
#        datum  vaderkod  temp_max icon        dag  antal_events
# 0 2026-04-29         3      12.0   🌥️  Ons 29/04            10
# 1 2026-04-30        51      18.0   🌧️  Tor 30/04            26
# 2 2026-05-01         1      23.0   🌤️  Fre 01/05            20
# 3 2026-05-02         3      22.0   🌥️  Lör 02/05            24
# 4 2026-05-03        51      14.0   🌧️  Sön 03/05            17
# 5 2026-05-04         3      18.0   🌥️  Mån 04/05             4
# 6 2026-05-05         3      13.0   🌥️  Tis 05/05             5

# %% [markdown]
# ## Visualisera - vad händer i Stockholm i veckan?

# %%
from matplotlib.font_manager import FontProperties

# Färgpalett
WHITE = "#FDFEFE"
GRAY_1 = "#CCCCCC"
GRAY_2 = "#888888"
GRAY_3 = "#444444"
GRAY_LIGHT = "#D5D8DC"
BLUE_DARK ="#2E4057"
PINK = "#FF6666"

# Identifiera soligaste dagarna (fredag och lördag)
solig = df_merged["vaderkod"].isin([0, 1, 2, 3])
regnig = df_merged["vaderkod"].isin([51, 67, 71, 80, 81, 82])

# Färg per stapel — fredagen mörkblå, resten ljusgrå
farger = []
for _, row in df_merged.iterrows():
    if row["vaderkod"] in [0, 1, 2] and row["temp_max"] >= 20:
        farger.append(PINK)
    else:
        farger.append(GRAY_LIGHT)

# Rita graf
fig, ax = plt.subplots(figsize=(13, 6))
fig.patch.set_facecolor(WHITE)
ax.set_facecolor(WHITE)

x = np.arange(len(df_merged))

bars = ax.bar(x, df_merged["antal_events"], color=farger, width=0.6,
              edgecolor="none", zorder=2)

# Väderikon + temperatur ovanför varje stapel
emoji_font = FontProperties(family="Segoe UI Emoji")
y_topp = df_merged["antal_events"].max()

for i, row in df_merged.iterrows():
    ax.text(i, row["antal_events"] + y_topp * 0.06,
            row["icon"], ha="center", va="bottom", fontsize=14,
            fontproperties=emoji_font)
    ax.text(i, row["antal_events"] + y_topp * 0.16,
            f"{int(row['temp_max'])}°",
            ha="center", va="bottom", fontsize=8, color=GRAY_2)

# Kommentar för sol
if solig.any():
    sol_idx = df_merged[solig]["temp_max"].idxmax()
    ax.annotate(
        text="Soligt & varmt —\nperfekt för utomhuskultur!",
        xy=(sol_idx, df_merged.loc[sol_idx, "antal_events"]),
        xytext=(sol_idx - 2.5, df_merged.loc[sol_idx, "antal_events"] + y_topp * 0.4),
        fontsize=10,
        color=GRAY_3,
        arrowprops=dict(
            arrowstyle="->",
            connectionstyle="arc3,rad=0.2",
            linewidth=1.3,
            color=BLUE_DARK
        )
    )

# # Kommentar för regn
# if regnig.any():
#     regn_idx = df_merged[regnig]["antal_events"].idxmax()
#     ax.annotate(
#         text="Regnigt —\nperfekt museumdag!",
#         xy=(regn_idx, df_merged.loc[regn_idx, "antal_events"]),
#         xytext=(regn_idx + 1.2, df_merged.loc[regn_idx, "antal_events"] + y_topp * 0.35),
#         fontsize=8,
#         color=GRAY_3,
#         arrowprops=dict(
#             arrowstyle="->",
#             connectionstyle="arc3,rad=-0.2",
#             linewidth=1.2,
#             color=GRAY_2
#         )
#     )

    # Legend
legend_items = [
    mpatches.Patch(color=PINK,  label="Dagen med bäst väder"),
    mpatches.Patch(color=GRAY_LIGHT, label="Övriga dagar"),
]
ax.legend(handles=legend_items, fontsize=8, frameon=False,
          labelcolor=GRAY_3, loc="upper left")

# Axlar och stil
ax.set_xticks(x)
ax.set_xticklabels(df_merged["dag"], fontsize=9, color=GRAY_2)
ax.set_ylabel("Antal evenemang", fontsize=10, color=GRAY_2)
ax.yaxis.set_label_coords(-0.06, 0.5)
ax.tick_params(axis="both", length=0, colors=GRAY_2)
ax.spines[["top", "right", "left"]].set_visible(False)
ax.spines["bottom"].set_color(GRAY_1)
ax.set_ylim(0, y_topp * 1.55)
ax.yaxis.grid(True, color=GRAY_1, linewidth=0.5, zorder=0)
ax.set_axisbelow(True)

ax.set_title(
    "Kulturutbud i Stockholm kommande dagar — fredag bjuder på 20+ grader och sol!",
    loc="left", fontsize=14, fontweight="bold", color=GRAY_3, pad=20
)
ax.set_xlabel("Veckodag", fontsize=10, color=GRAY_2)
ax.xaxis.set_label_coords(0.5, -0.1)

fig.tight_layout()
fig.savefig("data_images/veckan_events_väder.png", dpi=300)
plt.show()
